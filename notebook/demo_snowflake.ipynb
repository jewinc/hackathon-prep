# %% [markdown]
# # Imports, config, session and utilities

# %%
from pathlib import Path
import sys

# %%
current_file_path = Path().resolve()
sys.path.insert(0, str(current_file_path.parent))

# %%
import pandas as pd
# These import statement after adding parent file path to recognize src python files
from src.config import get_settings
from src.snowflake_client import create_snowpark_session

# %%
# Getting .env config and init snowflake session
settings = get_settings()
session = create_snowpark_session(settings)

# %% [markdown]
# # Main code

# %% [markdown]
# ## Programmatic access token (A faire qu'une seule fois)

# %%
query_setup_cortex = """
ALTER ACCOUNT SET CORTEX_ENABLED_CROSS_REGION = 'ANY_REGION';
"""
session.sql(query_setup_cortex).collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %%
user = "sushiatomique"
query = f"""ALTER USER {user.upper()} ADD PROGRAMMATIC ACCESS TOKEN pat;"""
res = session.sql(query).collect()

# Clé api pour le llm snowflake, à mettre dans votre .env
res[0][1]
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[6], line 3
#       1 user = "sushiatomique"
#       2 query = f"""ALTER USER {user.upper()} ADD PROGRAMMATIC ACCESS TOKEN pat;"""
# ----> 3 res = session.sql(query).collect()
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:295, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     293 try:
#     294     with ResourceUsageCollector() as resource_usage_collector:
# --> 295         result = func(*args, **kwargs)
#     296     resource_usage = resource_usage_collector.get_resource_usage()
#     297 finally:
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1148, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1144 kwargs["_emit_ast"] = is_ast_enabled()
#    1146 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1148 return func(*args, **kwargs)
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:774, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive, _emit_ast)
#     771     _, kwargs[DATAFRAME_AST_PARAMETER] = self._session._ast_batch.flush(stmt)
#     773 with open_telemetry_context_manager(self.collect, self):
# --> 774     return self._internal_collect_with_tag_no_telemetry(
#     775         statement_params=statement_params,
#     776         block=block,
#     777         log_on_exception=log_on_exception,
#     778         case_sensitive=case_sensitive,
#     779         **kwargs,
#     780     )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:847, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     831 def _internal_collect_with_tag_no_telemetry(
#     832     self,
#     833     *,
#    (...)    842     # we should always call this method instead of collect(), to make sure the
#     843     # query tag is set properly.
#     844     statement_params = track_data_source_statement_params(
#     845         self, statement_params or self._statement_params
#     846     )
# --> 847     return self._session._conn.execute(
#     848         self._plan,
#     849         block=block,
#     850         data_type=data_type,
#     851         _statement_params=create_or_update_statement_params_with_query_tag(
#     852             statement_params or self._statement_params,
#     853             self._session.query_tag,
#     854             SKIP_LEVELS_THREE,
#     855             collect_stacktrace=self._session.conf.get(
#     856                 "collect_stacktrace_in_query_tag"
#     857             ),
#     858         ),
#     859         log_on_exception=log_on_exception,
#     860         case_sensitive=case_sensitive,
#     861         **kwargs,
#     862     )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:648, in ServerConnection.execute(self, plan, to_pandas, to_iter, to_arrow, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     638 if (
#     639     is_in_stored_procedure()
#     640     and not block
#    (...)    643     )
#     644 ):  # pragma: no cover
#     645     raise NotImplementedError(
#     646         "Async query is not supported in stored procedure yet"
#     647     )
# --> 648 result_set, result_meta = self.get_result_set(
#     649     plan,
#     650     to_pandas,
#     651     to_iter,
#     652     **kwargs,
#     653     block=block,
#     654     data_type=data_type,
#     655     log_on_exception=log_on_exception,
#     656     case_sensitive=case_sensitive,
#     657     to_arrow=to_arrow,
#     658 )
#     659 if not block:
#     660     return result_set
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:426, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     421                 raise ne.with_traceback(tb) from None
#     423 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     424     e, debug_context=debug_context
#     425 )
# --> 426 raise ne.with_traceback(tb) from None
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:179, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     173 from snowflake.snowpark.context import (
#     174     _enable_dataframe_trace_on_error,
#     175     _enable_trace_sql_errors_to_dataframe,
#     176 )
#     178 try:
# --> 179     return func(*args, **kwargs)
#     180 except snowflake.connector.errors.ProgrammingError as e:
#     181     from snowflake.snowpark._internal.analyzer.select_statement import (
#     182         Selectable,
#     183     )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:770, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, to_arrow, **kwargs)
#     768     kwargs[DATAFRAME_AST_PARAMETER] = dataframe_ast
#     769 is_final_query = i == len(main_queries) - 1
# --> 770 result = self.run_query(
#     771     final_query,
#     772     to_pandas,
#     773     to_iter and is_final_query,
#     774     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     775     block=not is_last,
#     776     data_type=data_type,
#     777     async_job_plan=plan,
#     778     log_on_exception=log_on_exception,
#     779     case_sensitive=case_sensitive,
#     780     params=query.params,
#     781     ignore_results=ignore_results,
#     782     async_post_actions=post_actions,
#     783     to_arrow=to_arrow and is_final_query,
#     784     **kwargs,
#     785 )
#     786 placeholders[query.query_id_place_holder] = (
#     787     result["sfqid"] if not is_last else result.query_id
#     788 )
#     789 result_meta = get_new_description(self._cursor)
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:137, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     133     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     134         ex.cause
#     135     )
#     136 except Exception as ex:
# --> 137     raise ex
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:131, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     129     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     130 try:
# --> 131     return func(*args, **kwargs)
#     132 except ReauthenticationRequest as ex:
#     133     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     134         ex.cause
#     135     )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:544, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     542         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     543         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 544     raise ex
#     546 # fetch_pandas_all/batches() only works for SELECT statements
#     547 # We call fetchall() if fetch_pandas_all/batches() fails,
#     548 # because when the query plan has multiple queries, it will
#     549 # have non-select statements, and it shouldn't fail if the user
#     550 # calls to_pandas() to execute the query.
#     551 if block:
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:529, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     527     cached_analyze_attributes.clear_cache()
#     528 if block:
# --> 529     results_cursor = self.execute_and_notify_query_listener(
#     530         query, params=params, **kwargs
#     531     )
#     532     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     533 else:
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:459, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     455     err_query = ex.query if isinstance(ex, Error) else query
#     456     self.notify_query_listeners(
#     457         QueryRecord(sfqid, err_query, False), is_error=True, **notify_kwargs
#     458     )
# --> 459     raise ex
#     461 notify_kwargs["requestId"] = str(results_cursor._request_id)
#     462 self.notify_query_listeners(
#     463     QueryRecord(results_cursor.sfqid, results_cursor.query), **notify_kwargs
#     464 )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:450, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     448         notify_kwargs["dataframe_uuid"] = statement_params["_PLAN_UUID"]
#     449 try:
# --> 450     results_cursor = self._cursor.execute(query, **kwargs)
#     451 except Exception as ex:
#     452     notify_kwargs["requestId"] = None
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/connector/cursor.py:1142, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1138     is_integrity_error = (
#    1139         code == "100072"
#    1140     )  # NULL result in a non-nullable column
#    1141     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1142     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1143 return self
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)    280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)    295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:354, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     352 cursor.messages.append((error_class, error_value))
#     353 try:
# --> 354     cursor.errorhandler(connection, cursor, error_class, error_value)
#     355 except NotImplementedError:
#     356     # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     357     cursor._errorhandler(connection, cursor, error_class, error_value)
#
# File ~/Documents/Autre/hackathon/.venv/lib/python3.11/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# SnowparkSQLException: (1304): 01c21059-0001-8aaf-0000-0001fb0a52cd: 099401 (22000): Programmatic access token PAT already exists.

# %%
query = f"""
CREATE OR REPLACE NETWORK POLICY cortex_policy
ALLOWED_IP_LIST = (
  '0.0.0.0/0'
);
"""
session.sql(query).collect()

# %%
query = f"""
ALTER USER {user} SET NETWORK_POLICY = CORTEX_POLICY
"""

session.sql(query).collect()
# Out:
# [Row(status='Statement executed successfully.')]

# %% [markdown]
# ## Simple SQL DB interaction

# %%
df = pd.DataFrame({
    "id": [0, 1, 2],
    "text": ["text1", "text2", "text3"]
})

# %%
warehouse = "SNOWFLAKE_LEARNING_DB"
schema = "PUBLIC"
table_name = "TEST_TABLE"

query = f"""
CREATE TABLE IF NOT EXISTS {warehouse}.{schema}.{table_name} (
    id INT,
    text VARCHAR
);
"""

session.sql(query).collect()
# Out:
# [Row(status='TEST_TABLE already exists, statement succeeded.')]

# %%
for index, row in df.iterrows():
    insert_query = f"""
    INSERT INTO {warehouse}.{schema}.{table_name} (id, text)
    VALUES ({row['id']}, '{row['text']}');
    """
    session.sql(insert_query).collect()

# %%
query = f"""
SELECT * FROM {warehouse}.{schema}.{table_name}
LIMIT 2;
"""

res = session.sql(query).collect()

# %%
res
# Out:
# [Row(ID=0, TEXT='text1'), Row(ID=1, TEXT='text2')]

# %% [markdown]
# ## OCR and pdf reading

# %%
root_folder = Path("/".join(current_file_path.as_posix().split("/")[:-1]))

# %%
import pdfplumber

pdf_path = root_folder / "data" / "tableau_garantie.pdf"

# Read and parse PDF
text_content = ""

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text_content += page.extract_text() or ""

print(text_content)
# Out:
# DNIETNASGDT_WZ
# Assurén°:24747997-CHENG JEWIN
# N°Contrat:2108263;2108267
# Dated'effet:04/07/2024
# RéférencesCJ:MHPM2200002039S;MHPM2200002040S
# RéférencesCJC:M1/O04012-0001-S
# 24747997 - JEWIN CHENG
# BASEOBL-BASEFSS2023 SURCOOBL-SANTE
# RG GENERALE
# Contratobligatoire Contratobligatoire
# Hospitalisation
# Fraisdeséjour
# Fraisdeséjourconventionnés
# Fraisdeséjourconventionnés 600%BR 600%BR-contratdebase
# Fraisdeséjournonconventionnés
# 90%FRlimitéà600%BR,-contratde
# Fraisdeséjournonconventionnés 90%FRlimitéà600%BR
# base
# Honoraires
# Honorairesconventionnés
# OPTAM/OPTAM-CO:600%BR-
# OPTAM/OPTAM-CO:600%BR contratdebase
# Honorairesconventionnés
# NONOPTAM:TM+100%BR NONOPTAM:200%TM+600%BR
# -contratdebase
# Honorairesnonconventionnés
# 90%FRlimitéàTM+100%BR-
# Honorairesnonconventionnés 90%FRlimitéàTM+100%BR
# contratdebase
# Forfaitjournalierhospitalier
# Forfaitjournalierhospitalier 20€/jour 20€/jour-contratdebase
# Forfaitjournalierpsychiatrie 15€/jour 15€/jour-contratdebase
# ForfaitPatientUrgence
# ForfaitPatientUrgence 19,61€/jour 19,61€/jour-contratdebase
# ForfaitPatientUrgenceMinoré 8,49€/jour 8,49€/jour-contratdebase
# Participationforfaitaireacteslourds
# Participationforfaitaireacteslourds 24€/jour 24€/jour-contratdebase
# Chambreparticulièredenuit
# Chambreparticulièredenuit 4%PMSS/acte 4%PMSS/acte-contratdebase
# Chambredenuitpsychiatrie 4%PMSS/acte(1) 4%PMSS/acte-contratdebase(13)
# Chambreparticulièredejour
# Chambreparticulièredejour 4%PMSS 4%PMSS-contratdebase
# Chambredejourpsychiatrie 4%PMSS(1) 4%PMSS-contratdebase(13)
# Fraisd'accompagnant
# 1/7(SUITE)
# 60€/acte,Assuré(Assuré)-16ans 60€/acte-contratdebase,Assuré
# +75ans,Assuré(Assuré)-16ans (Assuré)-16ans +75ans,Assuré
# +75ans,Bénécifiaire(Ayant-droit) (Assuré)-16ans +75ans,Bénécifiaire
# -16ans +75ans,Bénécifiaire(Conjoint) (Ayant-droit)-16ans +75ans,
# Fraisd'accompagnant
# -16ans +75ans,Bénécifiaire(Enfant) Bénécifiaire(Conjoint)-16ans +75ans,
# -16ans +75ans Bénécifiaire(Enfant)-16ans +75ans
# Priseenchargeuniquementsi Priseenchargeuniquementsi
# bénéficiairede-16ansoude+75ans bénéficiairede-16ansoude+75ans
# 60€/acte,Assuré(Assuré)-16ans 60€/acte-contratdebase,Assuré
# +75ans,Assuré(Assuré)-16ans (Assuré)-16ans +75ans,Assuré
# +75ans,Bénécifiaire(Ayant-droit) (Assuré)-16ans +75ans,Bénécifiaire
# -16ans +75ans,Bénécifiaire(Conjoint) (Ayant-droit)-16ans +75ans,
# Fraisd'accompagnantpsychiatrie -16ans +75ans,Bénécifiaire(Enfant) Bénécifiaire(Conjoint)-16ans +75ans,
# -16ans +75ans,Limitéà120paracte Bénécifiaire(Enfant)-16ans +75ans,
# paran Limitéà120joursparan
# Priseenchargeuniquementsi Priseenchargeuniquementsi
# bénéficiairede-16ansoude+75ans bénéficiairede-16ansoude+75ans
# Dentaire
# Soinsetprothèses100%Santé
# Soinsetprothèses100%Santé
# Soinsetprothèses100%Santé FR-RO FR-RO-contratdebase
# Soinsautresque100%Santé
# SoinsdentairesremboursésSS
# SoinsdentairesremboursésSS 180%BR 180%BR-contratdebase
# Parodontologieetsoinsnonremb.SS
# 800€/acte-contratdebase,Plafond
# ParodontologienonrembourséeSS 800€/acte,Plafond:800€paran
# :800€paran
# Prothèsesautresque100%Santé
# Prothèsedentairepaniermodéré
# Prothèsedentairepaniermodéré 500%BR(2) 500%BR-contratdebase(14)
# Inlay-onlaypaniermodéré 180%BR 180%BR-contratdebase
# Prothèsedentairepanierlibre
# Prothèsedentairepanierlibre 500%BR(2) 500%BR-contratdebase(14)
# Inlay-onlay 180%BR 180%BR-contratdebase
# ProthèsedentairenonrembourséeSS
# 35%PMSS/acte-contratdebase,
# ProthèsedentairenonrembourséeSS:Bridge; 35%PMSS/acte,Plafond:3000€
# Plafond:3000€paran Limitéà4
# Couronneouadjonction paran,Limitéà4paracteparan
# acte(s)paran
# Implantologie
# ImplantologierembourséeSS
# ImplantologierembourséeSS 180%BR 180%BR-contratdebase
# ImplantologienonrembourséeSS
# 35%PMSS/acte,Limitéà2paracte 35%PMSS/acte-contratdebase
# ImplantdentairenonrembourséSS
# paran Limitéà2acte(s)paran
# Orthodontie
# OrthodontierembourséeSS
# OrthodontierembourséeSS 450%BR(2) 450%BR-contratdebase(14)
# OrthodontienonrembourséeSS
# 400€/trimestredetraitement-contrat
# 400€/trimestredetraitement(2),
# OrthodontienonrembourséeSS debase(14),Plafondàpartirdu1er
# Plafondàpartirdu1ersoin:3200€
# soin:3200€
# 2/7(SUITE)
# Optique
# Équipement100%Santé(classeA)
# Equipementoptique100%Santé
# Monture-de16ans100%Santé FR-RO(3) FR-RO-contratdebase(15)
# Verre-de16ans100%Santé FR-RO(4) FR-RO-contratdebase(16)
# Monture16anset+100%Santé FR-RO(5) FR-RO-contratdebase(17)
# Verre16anset+100%Santé FR-RO(6) FR-RO-contratdebase(18)
# Fraisd’adaptation100%Santé FR-RO FR-RO-contratdebase
# Fraisd’appairage100%Santé FR-RO FR-RO-contratdebase
# Supplémentverres100%Santé FR-RO FR-RO-contratdebase
# Équipementautreque100%Santé(classeB)
# Monture-16ans
# Monture-16ans:horsréseau;dansleréseau 100€/acte-RO(3) 100€/acte-RO-contratdebase(15)
# Verre-16ans
# Verre-16ans:dansleréseau,Verresimple 160€/acte-RO(4) 160€/acte-RO-contratdebase(16)
# 240€/acte-RO-contratdebase,
# 240€/acte-RO,Plafondsur1anà
# Verre-16ans:horsréseau,Verrecomplexe Plafondsur1anàdated'achat:2
# dated'achat:2verres
# verres
# Verre-16ans:horsréseau,Verresimple 80€/acte-RO(4) 80€/acte-RO-contratdebase(16)
# Verre-16ans:dansleréseau,Verrecomplexe 300€/acte-RO(4) 300€/acte-RO-contratdebase(16)
# Verre-16ans:horsréseau,Verretrèscomplexe 260€/acte-RO(4) 350€/acte-RO-contratdebase(16)
# Verre-16ans:dansleréseau,Verretrèscomplexe 350€/acte-RO(4) 440€/acte-RO-contratdebase(16)
# Monture16anset+
# Monture16anset+:horsréseau;dansleréseau 100€/acte-RO(5) 100€/acte-RO-contratdebase(17)
# Verres16anset+
# Verres16anset+:horsréseau,Verresimple 80€/acte-RO(6) 80€/acte-RO-contratdebase(18)
# 160€/acte-RO-contratdebase,
# 160€/acte-RO,Plafondsur2ansà
# Verres16anset+:dansleréseau,Verresimple Plafondsur2ansàdated'achat:2
# dated'achat:2verres
# verres
# Verres16anset+:horsréseau,Verrecomplexe 240€/acte-RO(6) 240€/acte-RO-contratdebase(18)
# Verres16anset+:dansleréseau,Verrecomplexe 300€/acte-RO(6) 300€/acte-RO-contratdebase(18)
# Verres16anset+:horsréseau,Verretrèscomplexe 260€/acte-RO(6) 350€/acte-RO-contratdebase(18)
# Verres16anset+:dansleréseau,Verretrès
# 350€/acte-RO(6) 440€/acte-RO-contratdebase(18)
# complexe
# LentillesprescritesrembourséesSS
# LentillesprescritesrembourséesSS 12%PMSS(7) 12%PMSS-contratdebase(19)
# LentillesprescritesnonrembourséesSS
# LentillesprescritesnonrembourséesSS 12%PMSS(7) 12%PMSS-contratdebase(19)
# Chirurgieoptiqueréfractive
# Chirurgieoptiqueréfractive 35%PMSS/acte 35%PMSS/acte-contratdebase
# Équipementautreque100%Santé
# Fraisd'adaptationetSuppléments
# Fraisd’adaptation TM TM-contratdebase
# Supplémentverres TM TM-contratdebase
# 3/7(SUITE)
# Aidesauditives
# Équipement100%Santé
# Aideauditive100%Santé
# Aideauditiveoreillegauche100%Santé FR-RO(8) FR-RO-contratdebase(20)
# Aideauditiveoreilledroite100%Santé FR-RO(9) FR-RO-contratdebase(21)
# Équipementautreque100%Santé
# AideauditiverembourséSS
# Sibénéficiairede-20ansouatteintde Sibénéficiairede-20ansouatteintde
# cécité:60%BR cécité:60%BR-contratdebase
# Aideauditiveoreillegauche
# Sibénéficiairede+20ans:365%BR Sibénéficiairede+20ans:365%BR
# (8) -contratdebase(20)
# Sibénéficiairede-20ansouatteintde Sibénéficiairede-20ansouatteintde
# cécité:60%BR cécité:60%BR-contratdebase
# Aideauditiveoreilledroite
# Sibénéficiairede+20ans:365%BR Sibénéficiairede+20ans:365%BR
# (9) -contratdebase(21)
# Accessoiresetfournitures
# Aideauditive-Accessoires TM TM-contratdebase
# TM-contratdebase,Limitéà20
# Aideauditive-Piles TM,Limitéà20paquetsparan
# paquetsparan
# 30€-contratdebase,Plafond:30€
# Aideauditive-AccessoiresNR:PILES 30€,Plafond:30€paran
# paran
# Soinscourants
# Consultations,Visites
# Généralisteconventionné
# OPTAM/OPTAM-CO:130%BR-
# OPTAM/OPTAM-CO:130%BR
# contratdebase
# NONOPTAMettauxSS100%:
# NONOPTAMettauxSS100%:
# Généralisteconventionné 100%BR
# 130%BR-contratdebase
# NONOPTAMetautretaux:TM+
# NONOPTAMetautretaux:200%TM
# 80%BR
# +100%BR-contratdebase
# Généralistenonconventionné
# SitauxSS100%:130%BR-contrat
# SitauxSS100%:100%BR debase
# Généralistenonconventionné
# Siautretaux:TM+80%BR Siautretaux:200%TM+100%BR-
# contratdebase
# Spécialisteconventionné
# OPTAM/OPTAM-CO:230%BR-
# contratdebase
# OPTAM/OPTAM-CO:230%BR NONOPTAMettauxSS100%:TM+
# Spécialisteconventionné
# NONOPTAM:TM+100%BR 230%BR-contratdebase
# NONOPTAMetautretaux:200%TM
# +200%BR-contratdebase
# Spécialistenonconventionné
# SitauxSS100%:TM+230%BR-
# contratdebase
# Spécialistenonconventionné TM+100%BR
# Siautretaux:200%TM+200%BR-
# contratdebase
# Honorairesmédicaux
# Actestechniquesmédicauxconventionnés
# OPTAM/OPTAM-CO:300%BR-
# contratdebase
# OPTAM/OPTAM-CO:300%BR NONOPTAMettauxSS100%:TM+
# Actestechniquesmédicauxconventionnés
# NONOPTAM:TM+100%BR 300%BR-contratdebase
# NONOPTAMetautretaux:200%TM
# +270%BR-contratdebase
# 4/7(SUITE)
# Actestechniquesmédicauxnonconv.
# SitauxSS100%:TM+300%BR-
# contratdebase
# Actestechniquesmédicauxnonconv. TM+100%BR
# Siautretaux:200%TM+270%BR-
# contratdebase
# Actesd'imageriemédicaleconventionnés
# OPTAM/OPTAM-CO:230%BR-
# contratdebase
# OPTAM/OPTAM-CO:230%BR NONOPTAMettauxSS100%:TM+
# Actesd'imageriemédicaleconventionnés
# NONOPTAM:TM+100%BR 230%BR-contratdebase
# NONOPTAMetautretaux:200%TM
# +200%BR-contratdebase
# Actesd'imageriemédicalenonconv.
# SitauxSS100%:TM+230%BR-
# contratdebase
# Actesd'imageriemédicalenonconv. TM+100%BR
# Siautretaux:200%TM+200%BR-
# contratdebase
# Actesd'imageriemédicalenonremboursés
# Actesd'imageriemédicalenonremboursés:Scanner 7,5%PMSS,Plafondsur1an:7,5% 7,5%PMSS-contratdebase,Plafond
# Pré-Implantaire duPMSS sur1an:7,5%duPMSS
# Médecineadditionnelleetdeprévention
# OstéodensitométrienonrembourséeSS
# OstéodensitométrienonrembourséeSS 50€/acte 50€/acte-contratdebase
# Honorairesmédicaux
# Honorairesparamédicaux
# Honorairesparamédicaux 200%BR 200%BR-contratdebase
# PsychologuerembourséSS
# 100%BR-RO,Limitéà1paracte
# Entretiend'évaluation -
# paran
# 100%BR-RO,Limitéà11paracte
# Séanced'accompagnement -
# paran
# Analysesetexamensdelaboratoire
# Analysesetexamensdelaboratoire 85%BR 85%BR-contratdebase
# AnalysesetexamensdelaboratoireNR
# AnalysesetexamensdelaboratoireNR 2%PMSS(10) 2%PMSS-contratdebase(22)
# Matérielmédical
# Matérielmédical 435%BR 435%BR-contratdebase
# Fraisdetransportsanitaires
# Fraisdetransportsanitaires TM TM-contratdebase
# Fraisdetransporthospitalisation
# Fraisdetransporthospi.médicale TM TM-contratdebase
# Fraisdetransporthospi.chirurgicale TM TM-contratdebase
# Fraisdetransportmaisondeconval. TM TM-contratdebase
# Participationforfaitaireacteslourds
# Participationforfaitaireacteslourds 24€/jour 24€/jour-contratdebase
# Curethermale
# HonorairesettraitementremboursésSS
# HonorairesettraitementremboursésSS 10%PMSS(11) 10%PMSS-contratdebase(23)
# HébergementetTransportremboursésSS
# 5/7(SUITE)
# HébergementetTransportremboursésSS 10%PMSS(11) 10%PMSS-contratdebase(23)
# HébergementetTransportnonremboursés
# HébergementetTransportnonremboursés:Cure 10%PMSS,Plafondsur1an:10% 10%PMSS-contratdebase,Plafond
# partiellementacceptée duPMSS sur1an:10%duPMSS
# Médicaments
# Médicamentsremboursésà65%
# Médicamentsremboursésà65% TM TM-contratdebase
# Médicamentsremboursésà30%
# Médicamentsremboursésà30% TM TM-contratdebase
# Médicamentsremboursésà15%
# Médicamentsremboursésà15% TM TM-contratdebase
# MédicamentsnonremboursésSS
# MédicamentsnonremboursésSS 2%PMSS(10) 2%PMSS-contratdebase(22)
# 2%PMSS,Plafondsur1an:2%du 2%PMSS-contratdebase,Plafond
# ContraceptifsnonremboursésSS
# PMSS sur1an:2%duPMSS
# VaccinsNR-Horsanti-grippe 15€(12) 15€-contratdebase(24)
# VaccinsNR-Anti-grippe 15€(12) 15€-contratdebase(24)
# Médecineadditionnelleetdeprévention
# Médecineadditionnelle
# Médecineadditionnelle:Diététique;Ergothérapie;
# Ostéopathe;Homéopathe;Psychothérapie;
# Psychomotricien;Chiropracteur;Etiopathe; 5%PMSS,Plafondsur1an:5%du 5%PMSS-contratdebase,Plafond
# Sophrologie;Psychologue;Nutritionniste;Acupuncture; PMSS sur1an:5%duPMSS
# Pédicurierefusée;Podologue;MicroKinésie;Méthode
# Mézières;Réflexologie;Hypnothérapie
# Plafondcommun:lalimitationdelaprestation(ennombred'actes,enduréeouenmontant)concerneetrassembleplusieursgaranties.
# (1)Plafondcommun-Limitéà120paracteparan (2)Plafondcommun-Plafond:3000€paran
# (3)Plafondcommun-Plafondsur1anàdated'achat:1monture (4)Plafondcommun-Plafondsur1anàdated'achat:2verres
# (5)Plafondcommun-Plafondsur2ansàdated'achat:1monture (6)Plafondcommun-Plafondsur2ansàdated'achat:2verres
# (7)Plafondcommun-Plafondsur1an:12%duPMSS (8)Plafondcommun-Limitéà1appareilsur4ans
# (9)Plafondcommun-Limitéà1appareilsur4ans (10)Plafondcommun-Plafondsur1an:2%duPMSS
# (11)Plafondcommun-Plafondsur1an:10%duPMSS (12)Plafondcommun-Plafond:15€paran
# (13)Plafondcommun-Limitéà120joursparan (14)Plafondcommun-Plafond:3000€paran
# (15)Plafondcommun-Plafondsur1anàdated'achat:1monture (16)Plafondcommun-Plafondsur1anàdated'achat:2verres
# (17)Plafondcommun-Plafondsur2ansàdated'achat:1monture (18)Plafondcommun-Plafondsur2ansàdated'achat:2verres
# (19)Plafondcommun-Plafondsur1an:12%duPMSS (20)Plafondcommun-Limitéà1appareilsur4ans
# (21)Plafondcommun-Limitéà1appareilsur4ans (22)Plafondcommun-Plafondsur1an:2%duPMSS
# (23)Plafondcommun-Plafondsur1an:10%duPMSS (24)Plafondcommun-Plafond:15€paran
# 6/7(SUITE)
# Le100%Santévouspermetd’accéderàuneoffresansresteàchargesurunesélectiond’équipementsendentaire,optiqueetpourlesaidesauditives.Lespaniers
# 100%SantéserontprisenchargeintégralementparlaSécuritésocialeetlacomplémentairesanté.
# Ensecteurnonconventionné,lesremboursementssonteffectuéssurlabasedutarifd'autorité.
# BR :BasedeRemboursementdelaSécuritésociale.
# FR:FraisRéels.
# RO:ParticipationduRégimeObligatoire.
# PMSS:PlafondMensueldelaSécuritésocialeenvigueurau1erjanvierdel'année.VoustrouverezlavaleurduPMSSenconsultant:ameli.fr.
# PASS:PlafondAnnueldelaSécuritésocialeenvigueurau1erjanvierdel'année.
# SS:Sécuritésociale.
# NR:NonRemboursable.
# HN:HorsNomenclature.
# TM:TicketModérateur;correspondàlapartiedelaBasedeRemboursement(BR)restantàchargedel’assuréaprèsleremboursementdelaSécuritésociale.
# Tarifsdeconvention:TarifsdessoinsrégisparconventionsentrelesprofessionnelsdesantéetlesorganismesdeSécuritésociale.
# Tarif d’autorité : Le tarif d’autorité est un barème tarifaire qui réglemente le remboursement des actes dispensés par un médecin n’ayant pas adhéré à une
# convention.EncomparaisonduTarifdeconvention, lemontantderemboursementduTarifd’autoritéesttrèsfaible.
# OPTAM:OptionPratiqueTarifaireMaîtrisée/OPTAM-CO:OptionPratiqueTarifaireMaîtrisée-ChirurgieObstétrique.
# Les tauxde remboursement exprimés pour les garanties Pharmacie correspondent auxtauxdu régime général de la Sécurité sociale. Ces tauxpeuvent être
# différentspourcertainsrégimeslocauxouspéciauxdeSécuritésociale.
# Pour les contratsresponsable la prise en charge desaides auditives de classe IIest limitée à 1700 €TTC par aide auditive (hors accessoires)ycompris le
# remboursementdelaSécuritésociale
# Saufprécisioncontrairedanslesgaranties,lesplafondss'appliquentparbénéficiaire.
# Pourlesconditionsderemboursementetlesjustificatifsàfournir,seréférerauxConditionsGénérales/RèglementMutualisteducontrat
# Pourlescontratsresponsablescollectifsobligatoires,lapriseenchargeestassuréeaumoinsàhauteurduTM+25% pourlesprothèsesdentaireshorspanier100
# %santéetl'orthodontieetàhauteurduTMpourlessoinsdentaires.Lesprothèsesdentairesdupanier100%santésontprisesenchargeintégralement(dansla
# limitedesHonorairesLimitesdeFacturation).
# Pourlescontratsresponsablescollectifsfacultatifsetindividuels,lapriseenchargeestassuréeàhauteurduTMpourlesprothèsesdentaires, lessoinsdentaires
# etl'orthodontie.
# 7/7

# %%
image_path = root_folder / "data" / "id_card.jpg"  # adjust filename as needed

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(use_angle_cls=True, lang='en')
image_path = root_folder / "data" / "id_card.jpg"

result = ocr.ocr(str(image_path))
for line in result[0]:
    print(line[1][0])  # prints the detected text

# %% [markdown]
# ## LLM usage

# %%
from openai import OpenAI

client = OpenAI(api_key=settings.openai_api_key, base_url=settings.openai_api_base)

prompt = "Explain what machine learning is in 2 sentences."

response = client.chat.completions.create(
    model="claude-3-7-sonnet",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# Machine learning is a subset of artificial intelligence where computer systems learn patterns from data and improve their performance on specific tasks without being explicitly programmed. These systems analyze large datasets to identify relationships, make predictions, or take actions, gradually enhancing their accuracy through experience rather than following pre-defined rules.

# %%
# Alternative: Use Cortex via SQL instead of the Python SDK
prompt = "Explain what is an insurance."

response = session.sql(f"""
    SELECT SNOWFLAKE.CORTEX.COMPLETE('claude-3-7-sonnet', '{prompt}')
""").collect()

print(response[0][0])
# Out:
# # Insurance Explained
#
# Insurance is a financial arrangement where an individual or entity (the policyholder) pays a regular fee (premium) to an insurance company in exchange for a promise of compensation in case of specific losses, damages, or events.
#
# ## Key Elements of Insurance:
#
# 1. **Risk Transfer**: Insurance transfers the financial risk of certain events from the policyholder to the insurer.
#
# 2. **Premiums**: Regular payments made to maintain coverage.
#
# 3. **Policy**: A contract detailing what is covered, exclusions, limits, and conditions.
#
# 4. **Claims**: Requests for compensation when covered events occur.
#
# 5. **Deductibles**: The amount the policyholder must pay before insurance coverage begins.
#
# ## Common Types of Insurance:
#
# - Health insurance
# - Auto insurance
# - Homeowners/renters insurance
# - Life insurance
# - Disability insurance
# - Business insurance
#
# Insurance works on the principle of risk pooling—many people contribute to a fund that pays out to the few who experience losses, making potentially devastating financial burdens manageable through shared risk.

# %% [markdown]
# # Close session

# %%
session.close()
